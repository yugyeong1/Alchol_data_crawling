# %%
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver.common.by import By
import numpy as np

# %%
from selenium.common.exceptions import ElementNotInteractableException, ElementClickInterceptedException, NoSuchElementException

df_alchol = pd.DataFrame(columns = ['name', 'percent', 'category', 'produce', 'supply', 'img_url'])
driver = webdriver.Chrome(executable_path='chromedriver')
index = 0

for x in range(1, 806+1):
    url = 'https://business.veluga.kr/search/result/?page=' + str(x)
    driver.get(url)

    print("현재 " + str(x) + "페이지 크롤링 중")
 
    for i in range(1, 20+1):
        
        time.sleep(3)
        base_xpath = '//*[@id="__next"]/div/div/div[1]/a['
        tail_xpath = ']/div[1]/img'
        url_xpath = base_xpath + str(i) + tail_xpath
        
        try: 
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)

            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]

            index = index + 1

        except ElementNotInteractableException:
            print(" pass")

            url = 'https://business.veluga.kr/search/result/?page=' + str(x)
            driver.get(url)

            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass


        except ElementClickInterceptedException:
            print(" pass")
            url = 'https://business.veluga.kr/search/result/?page=' + str(x)
            driver.get(url)
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass

        except NoSuchElementException:
            print( " NoSuchElementException")
            url = 'https://business.veluga.kr/search/result/?page=' + str(x)
            driver.get(url)
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass

        except IndexError:
            print("IndexError")
            url = 'https://business.veluga.kr/search/result/?page=' + str(x)
            driver.get(url)
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass

        driver.back()   

df_alchol.to_csv('alchol_crawling_df')

# %%
## 국산 맥주

# try, except 문에서 처리할 오류 임포트
from selenium.common.exceptions import ElementNotInteractableException, ElementClickInterceptedException, NoSuchElementException

driver = webdriver.Chrome('C:/Users/5-12/chromedriver') 

alchol_df = pd.DataFrame(columns = ['name', 'percent', 'category', 'produce', 'supply', 'img_url'])

index = 0

for x in range(1, 806+1):
    url = 'https://business.veluga.kr/search/result/?page=' + str(x)
    driver.get(url)

    print("현재 " + str(x) + "페이지 크롤링 중")
 
    for i in range(1, 20+1):
        
        time.sleep(6)
        base_xpath = '//*[@id="__next"]/div/div/div[1]/a['
        tail_xpath = ']/div[1]/img'
        url_xpath = base_xpath + str(i) + tail_xpath
        
        try: 
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(6)


            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')


            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text

            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text
             
            alchol_df.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]


            index = index + 1


        except ElementNotInteractableException:
            print(url_xpath + " pass")
            pass

        except ElementClickInterceptedException:
            print(url_xpath + " pass")
            pass
            
        except IndexError:
            print(url_xpath, "IndexError")
            pass
    
        except NoSuchElementException:
            print(url_xpath + " NoSuchElementException")
            pass
        
        driver.back()   
    

alchol_df.to_csv('alchol_crawling1')
# Out:
# C:\Users\5-12\AppData\Local\Temp\ipykernel_5676\2758704950.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/5-12/chromedriver')
# 현재 1페이지 크롤링 중
# 현재 2페이지 크롤링 중
# //*[@id="__next"]/div/div/div[1]/a[4]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[13]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[18]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[19]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[20]/div[1]/img NoSuchElementException
# 현재 3페이지 크롤링 중
# //*[@id="__next"]/div/div/div[1]/a[1]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[4]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[13]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[18]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[19]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[20]/div[1]/img NoSuchElementException
# 현재 4페이지 크롤링 중
# //*[@id="__next"]/div/div/div[1]/a[1]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[4]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[13]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[18]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[19]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[20]/div[1]/img NoSuchElementException
# 현재 5페이지 크롤링 중
# //*[@id="__next"]/div/div/div[1]/a[1]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[4]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[13]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[18]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[19]/div[1]/img NoSuchElementException
# //*[@id="__next"]/div/div/div[1]/a[20]/div[1]/img NoSuchElementException

# %%
from selenium.common.exceptions import ElementNotInteractableException, ElementClickInterceptedException, NoSuchElementException

df_alchol = pd.DataFrame(columns = ['name', 'percent', 'category', 'produce', 'supply', 'img_url'])
driver = webdriver.Chrome(executable_path='chromedriver')
index = 0

for x in range(6,34+1):
    url = 'https://business.veluga.kr/search/result/?page=' + str(x) + '&drink_type_id=2&drink_style_id=-1'
    driver.get(url)

    print("현재 " + str(x) + "페이지 크롤링 중")
 
    for i in range(1, 20+1):
        
        time.sleep(3)
        base_xpath = '//*[@id="__next"]/div/div/div[1]/a['
        tail_xpath = ']/div[1]/img'
        url_xpath = base_xpath + str(i) + tail_xpath
        
        try: 
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)


            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]

            index = index + 1

        except ElementNotInteractableException:
            print(" pass")
            
            url = 'https://business.veluga.kr/search/result/?page=' + str(x) + '&drink_type_id=2&drink_style_id=-1'
            driver.get(url)

            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass


        except ElementClickInterceptedException:
            print(" pass")
            url = 'https://business.veluga.kr/search/result/?page=' + str(x) + '&drink_type_id=2&drink_style_id=-1'
            driver.get(url)
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass

        except NoSuchElementException:
            print( " NoSuchElementException")
            url = 'https://business.veluga.kr/search/result/?page=' + str(x) + '&drink_type_id=2&drink_style_id=-1'
            driver.get(url)
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass

        except IndexError:
            print("IndexError")
            url = 'https://business.veluga.kr/search/result/?page=' + str(x) + '&drink_type_id=2&drink_style_id=-1'
            driver.get(url)
            click = driver.find_element(By.XPATH, url_xpath)
            driver.execute_script("arguments[0].click();", click)
            time.sleep(3)
            image_element = driver.find_elements(By.XPATH,'//*[@id="__next"]/div/div/div[1]/img')[0]
            image_td = image_element.get_attribute('src')

            name =  driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/div[2]/div[1]/h1').text
            
            percent =  driver.find_element(By.XPATH,"//th[contains(text(), '도수')]")
            percent_td = percent.find_element(By.XPATH,"following-sibling::td").text

            category =  driver.find_element(By.XPATH,"//th[contains(text(), '스타일')]")
            category_td = category.find_element(By.XPATH,"following-sibling::td").text

            produce =  driver.find_element(By.XPATH,"//th[contains(text(), '제조사')]")
            produce_td = produce.find_element(By.XPATH,"following-sibling::td").text

            supply = driver.find_element(By.XPATH,"//th[contains(text(), '공급사')]")
            supply_td = supply.find_element(By.XPATH,"following-sibling::td").text

            df_alchol.loc[index] = [name, percent_td, category_td, produce_td, supply_td, image_td]
            index = index + 1
            i+1
            pass

      
        


        driver.back()

# %%
category = alchol_df['category'].str.split(' ')

# %%
alchol_df = pd.read_csv('alchol_df', index_col= 0)

# %%
alchol_df
# Out:
#                        name percent   category      produce       supply  \
# 0                       이모꼬   25.0%  일반 소주 증류식       오오시마주조       (주)엘오엘
# 1                      이제우린   16.5%      일반 소주       맥키스컴퍼니       맥키스컴퍼니
# 2                       529   20.0%  일반 소주 증류식       오오시마주조       (주)엘오엘
# 3                   처음처럼 새로   16.0%  일반 소주 희석식       롯데칠성음료  롯데칠성음료 국내부문
# 4              진로 1924 헤리티지   30.0%  일반 소주 증류식     하이트진로 국산     하이트진로 국산
# ..                      ...     ...        ...          ...          ...
# 482  플로렌티나 유기농 버진 스파클링 레드프룻    0.0%        논알콜    도멘 피에르 차빈  주식회사 테이스트버드
# 483    플로렌티나 유기농 버진 스파클링 피치    0.0%        논알콜    도멘 피에르 차빈  주식회사 테이스트버드
# 484    빅드롭 무알콜 파인 트레일 페일 에일    0.5%     논알콜 맥주    하비스톤 브루어리    비더블유아이코리아
# 485          보테가 스파클링 제로 로제    0.0%     논알콜 와인      보테가 비나이       더바인컴퍼니
# 486                   피코 노바    0.3%        논알콜  브뤼셀 비어 프로젝트          비어로
#
#                                                img_url
# 0    https://cdn.veluga.kr/files/supplier/341/drink...
# 1    https://cdn.veluga.kr/drinks/21469/main/e1debe...
# 2    https://cdn.veluga.kr/files/supplier/341/drink...
# 3    https://cdn.veluga.kr/drinks/0/main/5950adf3b4...
# 4    https://cdn.veluga.kr/drinks/0/main/7330fa262e...
# ..                                                 ...
# 482  https://cdn.veluga.kr/files/supplier/75/drinks...
# 483  https://cdn.veluga.kr/files/supplier/75/drinks...
# 484  https://cdn.veluga.kr/files/supplier/13/drinks...
# 485  https://cdn.veluga.kr/files/supplier/119/drink...
# 486  https://assets.business.veluga.kr/media/public...
#
# [487 rows x 6 columns]

# %%
alchol_df['class'] = np.nan
alchol_df['category1'] = np.nan

# %%
category = alchol_df['category'].str.split(' ')

# %%
for i, j in enumerate(category):
    if len(j) == 3 :
        alchol_df['class'][i] = j[0] + " " + j[1]
        alchol_df['category1'][i] = j[2]

    elif len(j) == 1 :
        alchol_df['class'][i] = j[0]
# Out:
# C:\Users\5-12\AppData\Local\Temp\ipykernel_5676\3828118222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alchol_df['class'][i] = j[0] + " " + j[1]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_5676\3828118222.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alchol_df['category1'][i] = j[2]

# %%
for i,j in enumerate(category):
    if len(j) == 2 :
        if j[0] == '탁주' or j[0] == '과실주' or j[0] == '논알콜':
            alchol_df['class'][i] = j[0]
            alchol_df['category1'][i] = j[1]

        else :
            alchol_df['class'][i] = j[0] + " " +j[1]

# %%
for i,j in enumerate(category):
    if len(j) > 3 :
        alchol_df['class'][i] = j[0] + " " + j[1]
        alchol_df['category1'][i] = j[2] + " " + j[3]

# %%
alchol_df.to_csv('test')

# %%
alchol_df['category'].unique()
# Out:
# array(['일반 소주 증류식', '일반 소주', '일반 소주 희석식', '국산 맥주 라거', '국산 맥주 위트 에일',
#        '국산 맥주 스카치 에일', '국산 맥주 IPA', '국산 맥주', '국산 맥주 페일 에일', '국산 맥주 엠버 에일',
#        '국산 맥주 세종', '국산 맥주 기타', '국산 맥주 페일 라거', '국산 맥주 고제',
#        '국산 맥주 임페리얼 스타우트', '국산 맥주 쾰쉬', '국산 맥주 벨지안 에일', '국산 맥주 위트 비어',
#        '국산 맥주 엠버 라거', '국산 맥주 헬레스 라거', '국산 맥주 더블 IPA', '국산 맥주 포터',
#        '국산 맥주 세션 IPA', '국산 맥주 사워', '국산 맥주 스타우트', '국산 맥주 윗비어',
#        '국산 맥주 블론드 에일', '국산 맥주 프루트 비어', '국산 맥주 바이젠', '국산 맥주 브라운 에일',
#        '국산 맥주 필스너', '국산 맥주 둥켈', '국산 맥주 헤페 바이젠', '국산 맥주 다크 라거', '탁주',
#        '탁주 막걸리', '청주', '과실주 사이더', '과실주', '전통 소주 증류식', '전통 소주',
#        '기타 주류 스피릿', '기타 주류', '기타 주류 칵테일', '논알콜 기타', '논알콜 와인', '논알콜 맥주',
#        '논알콜'], dtype=object)

# %%
alchol_df
# Out:
#                        name percent   category      produce       supply  \
# 0                       이모꼬   25.0%  일반 소주 증류식       오오시마주조       (주)엘오엘
# 1                      이제우린   16.5%      일반 소주       맥키스컴퍼니       맥키스컴퍼니
# 2                       529   20.0%  일반 소주 증류식       오오시마주조       (주)엘오엘
# 3                   처음처럼 새로   16.0%  일반 소주 희석식       롯데칠성음료  롯데칠성음료 국내부문
# 4              진로 1924 헤리티지   30.0%  일반 소주 증류식     하이트진로 국산     하이트진로 국산
# ..                      ...     ...        ...          ...          ...
# 482  플로렌티나 유기농 버진 스파클링 레드프룻    0.0%        논알콜    도멘 피에르 차빈  주식회사 테이스트버드
# 483    플로렌티나 유기농 버진 스파클링 피치    0.0%        논알콜    도멘 피에르 차빈  주식회사 테이스트버드
# 484    빅드롭 무알콜 파인 트레일 페일 에일    0.5%     논알콜 맥주    하비스톤 브루어리    비더블유아이코리아
# 485          보테가 스파클링 제로 로제    0.0%     논알콜 와인      보테가 비나이       더바인컴퍼니
# 486                   피코 노바    0.3%        논알콜  브뤼셀 비어 프로젝트          비어로
#
#                                                img_url  class category1
# 0    https://cdn.veluga.kr/files/supplier/341/drink...  일반 소주       증류식
# 1    https://cdn.veluga.kr/drinks/21469/main/e1debe...  일반 소주       NaN
# 2    https://cdn.veluga.kr/files/supplier/341/drink...  일반 소주       증류식
# 3    https://cdn.veluga.kr/drinks/0/main/5950adf3b4...  일반 소주       희석식
# 4    https://cdn.veluga.kr/drinks/0/main/7330fa262e...  일반 소주       증류식
# ..                                                 ...    ...       ...
# 482  https://cdn.veluga.kr/files/supplier/75/drinks...    논알콜       NaN
# 483  https://cdn.veluga.kr/files/supplier/75/drinks...    논알콜       NaN
# 484  https://cdn.veluga.kr/files/supplier/13/drinks...    논알콜        맥주
# 485  https://cdn.veluga.kr/files/supplier/119/drink...    논알콜        와인
# 486  https://assets.business.veluga.kr/media/public...    논알콜       NaN
#
# [487 rows x 8 columns]
